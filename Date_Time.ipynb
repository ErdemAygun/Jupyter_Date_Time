# %%
import pandas as pd

# %%
pd.date_range("2022-09-26", "2022-10-10", freq="W")
# Out:
# DatetimeIndex(['2022-10-02', '2022-10-09'], dtype='datetime64[ns]', freq='W-SUN')

# %%
pd.date_range("2022-09-26", "2022-10-10", freq="W-MON")
# Out:
# DatetimeIndex(['2022-09-26', '2022-10-03', '2022-10-10'], dtype='datetime64[ns]', freq='W-MON')

# %%
pd.date_range("2022-09-26", "2022-09-30", freq="2D3H20MIN40S")
# Out:
# DatetimeIndex(['2022-09-26 00:00:00', '2022-09-28 03:20:40'], dtype='datetime64[ns]', freq='184840S')

# %%
pd.date_range("2022-09-26", "2022-09-30", freq="1D3H20MIN40S")
# Out:
# DatetimeIndex(['2022-09-26 00:00:00', '2022-09-27 03:20:40',
#                '2022-09-28 06:41:20', '2022-09-29 10:02:00'],
#               dtype='datetime64[ns]', freq='98440S')

# %%
pd.date_range("2022-09-01", freq="7D", periods=10)
# Out:
# DatetimeIndex(['2022-09-01', '2022-09-08', '2022-09-15', '2022-09-22',
#                '2022-09-29', '2022-10-06', '2022-10-13', '2022-10-20',
#                '2022-10-27', '2022-11-03'],
#               dtype='datetime64[ns]', freq='7D')

# %%
df = pd.read_csv("https://stooq.com/q/d/l/?s=cdr&d1=20200101&d2=20220114&i=d")
df
# Out:
#            Date     Open     High      Low    Close         Volume
# 0    2020-01-02  271.302  275.924  270.342  275.924  174088.134909
# 1    2020-01-03  276.112  278.814  270.441  275.152  253592.737636
# 2    2020-01-07  276.211  277.468  272.173  273.034  221256.642750
# 3    2020-01-08  272.747  273.034  266.788  270.441  233313.724433
# 4    2020-01-09  273.232  277.656  272.272  277.656  202579.986808
# ..          ...      ...      ...      ...      ...            ...
# 507  2022-01-10  196.573  197.622  186.180  186.180  407499.859755
# 508  2022-01-11  187.566  191.129  186.279  186.635  347083.110577
# 509  2022-01-12  187.368  194.652  184.101  193.999  529395.197632
# 510  2022-01-13  191.030  195.741  190.040  191.050  297485.809007
# 511  2022-01-14  190.990  193.346  187.763  189.050  259348.493824
#
# [512 rows x 6 columns]

# %%
df.dtypes
# Out:
# Date       object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume    float64
# dtype: object

# %%
df.Date = pd.to_datetime(df.Date, format="%Y-%m-%d")

# %%
df.dtypes
# Out:
# Date      datetime64[ns]
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume           float64
# dtype: object

# %%
df.Date
# Out:
# 0     2020-01-02
# 1     2020-01-03
# 2     2020-01-07
# 3     2020-01-08
# 4     2020-01-09
#          ...
# 507   2022-01-10
# 508   2022-01-11
# 509   2022-01-12
# 510   2022-01-13
# 511   2022-01-14
# Name: Date, Length: 512, dtype: datetime64[ns]

# %%
df.Date.dt.year
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 507    2022
# 508    2022
# 509    2022
# 510    2022
# 511    2022
# Name: Date, Length: 512, dtype: int64

# %%
df.Date.dt.month
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 507    1
# 508    1
# 509    1
# 510    1
# 511    1
# Name: Date, Length: 512, dtype: int64

# %%
df.Date.dt.day
# Out:
# 0       2
# 1       3
# 2       7
# 3       8
# 4       9
#        ..
# 507    10
# 508    11
# 509    12
# 510    13
# 511    14
# Name: Date, Length: 512, dtype: int64

# %%
df.Date.dt.day_of_week
# Out:
# 0      3
# 1      4
# 2      1
# 3      2
# 4      3
#       ..
# 507    0
# 508    1
# 509    2
# 510    3
# 511    4
# Name: Date, Length: 512, dtype: int64

# %%
df.Date.dt.weekday
# Out:
# 0      3
# 1      4
# 2      1
# 3      2
# 4      3
#       ..
# 507    0
# 508    1
# 509    2
# 510    3
# 511    4
# Name: Date, Length: 512, dtype: int64

# %%
df
# Out:
#           Date     Open     High      Low    Close         Volume
# 0   2020-01-02  271.302  275.924  270.342  275.924  174088.134909
# 1   2020-01-03  276.112  278.814  270.441  275.152  253592.737636
# 2   2020-01-07  276.211  277.468  272.173  273.034  221256.642750
# 3   2020-01-08  272.747  273.034  266.788  270.441  233313.724433
# 4   2020-01-09  273.232  277.656  272.272  277.656  202579.986808
# ..         ...      ...      ...      ...      ...            ...
# 507 2022-01-10  196.573  197.622  186.180  186.180  407499.859755
# 508 2022-01-11  187.566  191.129  186.279  186.635  347083.110577
# 509 2022-01-12  187.368  194.652  184.101  193.999  529395.197632
# 510 2022-01-13  191.030  195.741  190.040  191.050  297485.809007
# 511 2022-01-14  190.990  193.346  187.763  189.050  259348.493824
#
# [512 rows x 6 columns]

# %%
df.set_index("Date", inplace=True)
df.Close.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close.plot(figsize=(16,5), grid=True, color="red")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# start date: 2021-12-01, end date: 2022-01-13
df
# Out:
#                Open     High      Low    Close         Volume
# Date
# 2020-01-02  271.302  275.924  270.342  275.924  174088.134909
# 2020-01-03  276.112  278.814  270.441  275.152  253592.737636
# 2020-01-07  276.211  277.468  272.173  273.034  221256.642750
# 2020-01-08  272.747  273.034  266.788  270.441  233313.724433
# 2020-01-09  273.232  277.656  272.272  277.656  202579.986808
# ...             ...      ...      ...      ...            ...
# 2022-01-10  196.573  197.622  186.180  186.180  407499.859755
# 2022-01-11  187.566  191.129  186.279  186.635  347083.110577
# 2022-01-12  187.368  194.652  184.101  193.999  529395.197632
# 2022-01-13  191.030  195.741  190.040  191.050  297485.809007
# 2022-01-14  190.990  193.346  187.763  189.050  259348.493824
#
# [512 rows x 5 columns]

# %%
df.Close.loc["2021-12-01":"2022-01-13"].plot(figsize=(16,5), grid=True, color='red')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close.loc["2021-12-01":"2022-12-31"].plot(figsize=(16,5), grid=True, color='red')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close.loc["2021-12"].plot(figsize=(16,5), grid=True, color='red') # returns to whole year
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close.loc["2021"].plot(figsize=(16,5), grid=True, color='red')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close.resample("Y")

# %%
df.Close.resample("Y").mean()
# Out:
# Date
# 2020-12-31    343.030504
# 2021-12-31    194.473378
# 2022-12-31    193.381111
# Freq: A-DEC, Name: Close, dtype: float64

# %%
df.Close.resample("YS").mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close.resample("YS").mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# gets max value for every quarter
df.Close.resample("QS").max().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close.plot(figsize=(16,5), grid=True, color="red")

df.Close.rolling(40).mean().plot(figsize=(16,5), grid=True, color="green")
# Out:
# <AxesSubplot:xlabel='Date'>
